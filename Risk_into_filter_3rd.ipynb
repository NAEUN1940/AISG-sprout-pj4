# %%
# !git clone https://github.com/VinAIResearch/COVID19Tweet.git
# %cd COVID19Tweet
# !unzip -q WNUT-2020-Task-2-Dataset.zip -d data
# !find data -type f
# Out:
# fatal: destination path 'COVID19Tweet' already exists and is not an empty directory.
# /content/COVID19Tweet
# replace data/WNUT-2020-Task-2-Dataset/train.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace data/WNUT-2020-Task-2-Dataset/test.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace data/WNUT-2020-Task-2-Dataset/unlabeled_test_with_noise.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace data/WNUT-2020-Task-2-Dataset/valid.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# data/WNUT-2020-Task-2-Dataset/train.tsv
# data/WNUT-2020-Task-2-Dataset/test.tsv
# data/WNUT-2020-Task-2-Dataset/unlabeled_test_with_noise.tsv
# data/WNUT-2020-Task-2-Dataset/valid.tsv

# %%
# 1. 함수 가져오기
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer #문자를 숫자로 가져옴
from sklearn.linear_model import LogisticRegression #로지스틱회귀 사용
from sklearn.metrics import accuracy_score, f1_score, classification_report #정확도, 점수, 성능표 보기

# %%
# 2. 데이터 읽기
train_df = pd.read_csv("data/WNUT-2020-Task-2-Dataset/train.tsv", sep="\t") #탭으로 나눠져있음
valid_df = pd.read_csv("data/WNUT-2020-Task-2-Dataset/valid.tsv", sep="\t", header=None)
valid_df.columns = ['Id', 'Text', 'Label'] #헤더가 없다고 함 + 열 이름 할당하게 되어 이름도 다시 할당

# %%
# 3. 데이터 확인
train_df.head()
train_df.columns
train_df.shape
# Out:
# (6936, 3)

# %%
# 4. 입력과 정답 나누기

X_train = train_df["Text"].astype(str)
y_train = train_df["Label"].astype(str)

X_valid = valid_df["Text"].astype(str)
y_valid = valid_df["Label"].astype(str)

# %%
# 5. 텍스트 숫자화
vectorizer = TfidfVectorizer()

X_train_vec = vectorizer.fit_transform(X_train) #단어사전 만든 후 숫자로 바꿈
X_valid_vec = vectorizer.transform(X_valid) #train에서 만든 기준으로 숫자로만 바꾼다

# %%
# 6. 모델 학습
model = LogisticRegression(max_iter=1000) #로지스틱 회귀 모델 만들기
model.fit(X_train_vec, y_train) #학습 시작
# Out:
# LogisticRegression(max_iter=1000)

# %%
# 7. 예측
pred = model.predict(X_valid_vec)

# %%
# 8. 성능 확인
print(accuracy_score(y_valid, pred))
print(f1_score(y_valid, pred, pos_label="INFORMATIVE"))
print(classification_report(y_valid, pred))
# Out:
# 0.817
# 0.7941507311586051
#                precision    recall  f1-score   support
#
#   INFORMATIVE       0.85      0.75      0.79       472
# UNINFORMATIVE       0.80      0.88      0.84       528
#
#      accuracy                           0.82      1000
#     macro avg       0.82      0.81      0.81      1000
#  weighted avg       0.82      0.82      0.82      1000

# %%
# 9. 키워드 기반 위험 점수 설정
import re
import numpy as np
import pandas as pd

def clean_for_keyword(text):
    text = str(text).lower()

    text = text.replace("httpurl", " url ")
    text = text.replace("@user", " user ")

    text = re.sub(r"http\S+|www\S+", " url ", text)
    text = re.sub(r"@\w+", " user ", text)
    text = text.replace("#", "")

    text = re.sub(r"[^a-zA-Z0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    return text
# 범주별로 키워드 설정
risk_keyword_groups = {
    "case_growth": [
        "new cases", "confirmed cases", "confirmed", "positive cases",
        "tested positive", "cases", "case increase", "increase",
        "rising", "rise", "surge", "spike"
    ],

    "death_severity": [
        "death", "deaths", "dead", "died", "dies", "dying",
        "fatal", "fatality", "fatalities", "death toll"
    ],

    "medical_system": [
        "hospital", "hospitals", "hospitalized", "hospitalised",
        "icu", "ventilator", "ventilators",
        "hospital beds", "icu beds", "beds",
        "capacity", "overwhelmed", "patients"
    ],

    "testing_quarantine": [
        "test", "tests", "tested", "testing", "quarantine",
        "isolation", "isolated", "self isolate", "self isolation"
    ],

    "symptoms_infection": [
        "symptom", "symptoms", "infected", "infection", "outbreak",
        "spread", "spreading", "transmission", "exposed"
    ],

    "public_response": [
        "lockdown", "shutdown", "restriction", "restrictions",
        "emergency", "curfew", "ban", "closed", "closure"
    ]
}
# 초기 가중치
risk_group_weights = {
    "case_growth": 2,
    "death_severity": 3,
    "medical_system": 3,
    "testing_quarantine": 1,
    "symptoms_infection": 1,
    "public_response": 1
}

# %%
# 10. 키워드 매칭 함수
def contains_keyword(cleaned_text, keyword):
    keyword = keyword.lower()

    # 여러 단어로 된 phrase keyword
    if " " in keyword:
        return keyword in cleaned_text

    # 단일 단어 keyword
    tokens = cleaned_text.split()
    return keyword in tokens

def keyword_risk_score(text):
    cleaned = clean_for_keyword(text)

    total_score = 0
    matched = {}

    for group, keywords in risk_keyword_groups.items():
        group_matches = []

        for keyword in keywords:
            if contains_keyword(cleaned, keyword):
                group_matches.append(keyword)

        if group_matches:
            weight = risk_group_weights[group]
            total_score += weight
            matched[group] = group_matches

    return total_score, matched

# %%
# 11. Logistic Regression 예측 결과 + 키워드 점수 결합
def predict_info_with_risk(text):
    # 1. TF-IDF 변환
    text_vec = vectorizer.transform([str(text)])

    # 2. info/non-info 예측
    pred_label = model.predict(text_vec)[0]

    # 3. INFORMATIVE 확률 구하기
    proba = model.predict_proba(text_vec)[0]
    class_to_prob = dict(zip(model.classes_, proba))

    prob_informative = class_to_prob.get("INFORMATIVE", 0.0)
    prob_uninformative = class_to_prob.get("UNINFORMATIVE", 0.0)

    # 4. 키워드 위험 점수 계산
    keyword_score, matched_keywords = keyword_risk_score(text)

    # 5. 최종 위험 점수 계산
    final_score = 0

    if pred_label == "INFORMATIVE":
        final_score += 3

    if prob_informative >= 0.8:
        final_score += 2
    elif prob_informative >= 0.6:
        final_score += 1

    final_score += keyword_score

    # 6. 안전장치: 모델이 UNINFORMATIVE라고 강하게 판단하면 HIGH 방지
    if pred_label == "UNINFORMATIVE" and prob_informative < 0.5:
        final_score = min(final_score, 3)

    # 7. LOW / MEDIUM / HIGH 구분
    if final_score >= 9 and prob_informative >= 0.8:
        alert_level = "HIGH"
    elif final_score >= 5:
        alert_level = "MEDIUM"
    else:
        alert_level = "LOW"

    return {
        "Text": text,
        "pred_label": pred_label,
        "prob_informative": prob_informative,
        "prob_uninformative": prob_uninformative,
        "keyword_score": keyword_score,
        "matched_keywords": matched_keywords,
        "final_score": final_score,
        "alert_level": alert_level
    }

# %%
# 12. 예시 트윗으로 테스트
demo_texts = [
    "There are 500 new confirmed COVID-19 cases and 12 deaths in the city today.",
    "The local hospital is overwhelmed and ICU beds are almost full.",
    "I hate staying home because of coronavirus.",
    "New testing centers will open tomorrow for people with symptoms.",
    "Watching movies during quarantine is boring.",
    "Officials reported a sudden spike in infections after a large outbreak."
]

for text in demo_texts:
    result = predict_info_with_risk(text)
    print("=" * 100)
    for k, v in result.items():
        print(k, ":", v)
# Out:
# ====================================================================================================
# Text : There are 500 new confirmed COVID-19 cases and 12 deaths in the city today.
# pred_label : INFORMATIVE
# prob_informative : 0.9920083112405145
# prob_uninformative : 0.00799168875948555
# keyword_score : 5
# matched_keywords : {'case_growth': ['confirmed', 'cases'], 'death_severity': ['deaths']}
# final_score : 10
# alert_level : HIGH
# ====================================================================================================
# Text : The local hospital is overwhelmed and ICU beds are almost full.
# pred_label : UNINFORMATIVE
# prob_informative : 0.2191753437349958
# prob_uninformative : 0.7808246562650042
# keyword_score : 3
# matched_keywords : {'medical_system': ['hospital', 'icu', 'icu beds', 'beds', 'overwhelmed']}
# final_score : 3
# alert_level : LOW
# ====================================================================================================
# Text : I hate staying home because of coronavirus.
# pred_label : UNINFORMATIVE
# prob_informative : 0.19430828104413855
# prob_uninformative : 0.8056917189558614
# keyword_score : 0
# matched_keywords : {}
# final_score : 0
# alert_level : LOW
# ====================================================================================================
# Text : New testing centers will open tomorrow for people with symptoms.
# pred_label : UNINFORMATIVE
# prob_informative : 0.2459894957407569
# prob_uninformative : 0.7540105042592431
# keyword_score : 2
# matched_keywords : {'testing_quarantine': ['testing'], 'symptoms_infection': ['symptoms']}
# final_score : 2
# alert_level : LOW
# ====================================================================================================
# Text : Watching movies during quarantine is boring.
# pred_label : UNINFORMATIVE
# prob_informative : 0.20245224875518097
# prob_uninformative : 0.797547751244819
# keyword_score : 1
# matched_keywords : {'testing_quarantine': ['quarantine']}
# final_score : 1
# alert_level : LOW
# ====================================================================================================
# Text : Officials reported a sudden spike in infections after a large outbreak.
# pred_label : INFORMATIVE
# prob_informative : 0.5951421352287376
# prob_uninformative : 0.40485786477126234
# keyword_score : 3
# matched_keywords : {'case_growth': ['spike'], 'symptoms_infection': ['outbreak']}
# final_score : 6
# alert_level : MEDIUM

# %%
# 13. valid  데이터 전체에 후처리 작용
valid_results = []

for text in X_valid:
    valid_results.append(predict_info_with_risk(text))

valid_risk_df = pd.DataFrame(valid_results)

valid_risk_df.head()
# 위험 단계 분포 확인
valid_risk_df["alert_level"].value_counts()
# HIGH로 잡힌 트윗 확인
valid_risk_df[valid_risk_df["alert_level"] == "HIGH"][
    ["Text", "pred_label", "prob_informative", "keyword_score", "matched_keywords", "final_score", "alert_level"]
].head(20)
# MEDIUM으로 잡힌 트윗 확인
valid_risk_df[valid_risk_df["alert_level"] == "MEDIUM"][
    ["Text", "pred_label", "prob_informative", "keyword_score", "matched_keywords", "final_score", "alert_level"]
].head(20)
# Out:
#                                                  Text   pred_label  \
# 1   Second case DR 🇩🇴 The Canadian woman has not b...  INFORMATIVE
# 4   Report suggested that the actual number of und...  INFORMATIVE
# 9   UPDATE: the two people at our Hail Creek opera...  INFORMATIVE
# 16  IN PICTURES: NOA Mobile Public Address Van swi...  INFORMATIVE
# 17  The Taslee Palm City Estate in Maitama, Abuja,...  INFORMATIVE
# 18  Soooo.... more than 1000 people died above nor...  INFORMATIVE
# 21  There are eight new cases of #COVID19 in #Sask...  INFORMATIVE
# 22  240,000 Americans died from coronavirus and, w...  INFORMATIVE
# 24  New York statewide coronavirus total hits 22 a...  INFORMATIVE
# 25  NEWS: A permanent memorial is going to be set ...  INFORMATIVE
# 26  #KatieMiller is #StephenMillers new wife &amp;...  INFORMATIVE
# 27  i didn’t know I’ll wake up from the news of de...  INFORMATIVE
# 31  74 cases of #COVID19 today in TN😕.That takes t...  INFORMATIVE
# 32  Alberta reports second presumptive case of new...  INFORMATIVE
# 35  Just received this little nugget (quote) in te...  INFORMATIVE
# 37  Total Cases Of Coronavirus ( 1st March - 17th ...  INFORMATIVE
# 44  @USER @USER @USER A person who visited the nur...  INFORMATIVE
# 45  @USER COVID-19 deaths in the US have exceeded ...  INFORMATIVE
# 47  Many Africa countries still record just 1 or l...  INFORMATIVE
# 50  Wuhan reported no new coronavirus cases for th...  INFORMATIVE
#
#     prob_informative  keyword_score  \
# 1           0.886427              0
# 4           0.683655              2
# 9           0.753189              1
# 16          0.544316              2
# 17          0.688925              3
# 18          0.537942              3
# 21          0.889007              3
# 22          0.515683              3
# 24          0.900425              2
# 25          0.627939              6
# 26          0.826590              0
# 27          0.683343              2
# 31          0.923172              2
# 32          0.914757              0
# 35          0.592371              3
# 37          0.619314              2
# 44          0.861890              3
# 45          0.585225              6
# 47          0.537513              3
# 50          0.527122              4
#
#                                      matched_keywords  final_score alert_level
# 1                                                  {}            5      MEDIUM
# 4        {'case_growth': ['positive cases', 'cases']}            6      MEDIUM
# 9   {'testing_quarantine': ['test', 'tested', 'iso...            5      MEDIUM
# 16                      {'case_growth': ['increase']}            5      MEDIUM
# 17  {'case_growth': ['confirmed'], 'symptoms_infec...            7      MEDIUM
# 18              {'death_severity': ['died', 'dying']}            6      MEDIUM
# 21  {'case_growth': ['new cases', 'cases'], 'testi...            8      MEDIUM
# 22             {'death_severity': ['deaths', 'died']}            6      MEDIUM
# 24                         {'case_growth': ['cases']}            7      MEDIUM
# 25  {'death_severity': ['died'], 'medical_system':...           10      MEDIUM
# 26                                                 {}            5      MEDIUM
# 27  {'case_growth': ['confirmed cases', 'confirmed...            6      MEDIUM
# 31                         {'case_growth': ['cases']}            7      MEDIUM
# 32                                                 {}            5      MEDIUM
# 35                     {'death_severity': ['deaths']}            6      MEDIUM
# 37                         {'case_growth': ['cases']}            6      MEDIUM
# 44  {'case_growth': ['confirmed'], 'symptoms_infec...            8      MEDIUM
# 45  {'case_growth': ['confirmed'], 'death_severity...            9      MEDIUM
# 47  {'case_growth': ['cases'], 'testing_quarantine...            6      MEDIUM
# 50  {'case_growth': ['cases'], 'symptoms_infection...            7      MEDIUM

# %%
# 14. 키워드가 적절한지 확인
def has_group_keyword(text, keywords):
    cleaned = clean_for_keyword(text)
    return any(contains_keyword(cleaned, keyword) for keyword in keywords)

rows = []

for group, keywords in risk_keyword_groups.items():
    hit = train_df["Text"].apply(lambda x: has_group_keyword(x, keywords))

    total_hit = hit.sum()
    informative_hit = ((train_df["Label"] == "INFORMATIVE") & hit).sum()
    uninformative_hit = ((train_df["Label"] == "UNINFORMATIVE") & hit).sum()

    informative_ratio = informative_hit / total_hit if total_hit > 0 else 0

    rows.append({
        "group": group,
        "total_hit": total_hit,
        "informative_hit": informative_hit,
        "uninformative_hit": uninformative_hit,
        "informative_ratio": informative_ratio
    })

keyword_eval_df = pd.DataFrame(rows)
keyword_eval_df.sort_values("informative_ratio", ascending=False)
# Out:
#                 group  total_hit  informative_hit  uninformative_hit  \
# 1      death_severity       1891             1308                583
# 0         case_growth       2502             1712                790
# 3  testing_quarantine       1462              986                476
# 2      medical_system        922              513                409
# 4  symptoms_infection       1091              485                606
# 5     public_response        404              153                251
#
#    informative_ratio
# 1           0.691698
# 0           0.684253
# 3           0.674419
# 2           0.556399
# 4           0.444546
# 5           0.378713

# %%
# 15. 라벨 없는 데이터에 적용하고 CSV 저장
unlabeled_df = pd.read_csv(
    "data/WNUT-2020-Task-2-Dataset/unlabeled_test_with_noise.tsv",
    sep="\t",
    header=None
)

unlabeled_df.columns = ["Id", "Text"]

unlabeled_df.head()

unlabeled_results = []

for_texts = unlabeled_df["Text"].astype(str)

for text in for_texts:
    unlabeled_results.append(predict_info_with_risk(text))

unlabeled_risk_df = pd.DataFrame(unlabeled_results)

unlabeled_risk_df.head()
# Out:
#                                                 Text     pred_label  \
# 0  Fox Business' Lou Dobbs Self-Quarantines After...    INFORMATIVE
# 1  Results from UVRI showed the sample is positiv...    INFORMATIVE
# 2  Today or tomorrow, the number of #COVIDー19 cas...  UNINFORMATIVE
# 3  Ramsey County veterans experiencing negative f...  UNINFORMATIVE
# 4  The #Covid19 death rate in New Orleans is 7x h...  UNINFORMATIVE
#
#    prob_informative  prob_uninformative  keyword_score  \
# 0          0.626790            0.373210              1
# 1          0.909645            0.090355              2
# 2          0.289060            0.710940              2
# 3          0.244093            0.755907              0
# 4          0.357295            0.642705              3
#
#                     matched_keywords  final_score alert_level
# 0  {'testing_quarantine': ['tests']}            5      MEDIUM
# 1     {'case_growth': ['confirmed']}            7      MEDIUM
# 2         {'case_growth': ['cases']}            2         LOW
# 3                                 {}            0         LOW
# 4      {'death_severity': ['death']}            3         LOW

# %%
# 위험후보 Top 20 보기
level_rank = {
    "HIGH": 3,
    "MEDIUM": 2,
    "LOW": 1
}

unlabeled_risk_df["alert_rank"] = unlabeled_risk_df["alert_level"].map(level_rank)

top_risk = unlabeled_risk_df.sort_values(
    by=["alert_rank", "final_score", "prob_informative"],
    ascending=[False, False, False]
)

top_risk[
    ["Text", "pred_label", "prob_informative", "keyword_score", "matched_keywords", "final_score", "alert_level"]
].head(20)
# Out:
#                                                     Text   pred_label  \
# 5861   Suggestions for #covid reporting: #CovidS (hav...  INFORMATIVE
# 494    Aggiornamento Emergenza Coronavirus negli Stat...  INFORMATIVE
# 10094  COVID-19: Santa Clara County, CA (20-MAR-2020)...  INFORMATIVE
# 8427   Status of covid-19: - All non-essential busine...  INFORMATIVE
# 1972   The Department of Health has confirmed that 23...  INFORMATIVE
# 487    HTTPURL As of 9am on 21 March 2020, 72,818 peo...  INFORMATIVE
# 3842   COVID-19 UPDATE (March 21, 2020 | 5PM) Another...  INFORMATIVE
# 11793  Day 55: UK coronavirus #COVID19 update: 'As of...  INFORMATIVE
# 6947   UPDATE on coronavirus (#COVID19) testing in th...  INFORMATIVE
# 9776   30 more persons have tested #positive for #Cor...  INFORMATIVE
# 1987   It's been confirmed two women and two men, who...  INFORMATIVE
# 8797   We have 31 new cases of COVID-19 today in Albe...  INFORMATIVE
# 1213   A man in his 70s who tested positive for COVID...  INFORMATIVE
# 8461   Hull University Teaching Hospitals NHS Trust c...  INFORMATIVE
# 5469   Breaking from @USER A further 53 people who te...  INFORMATIVE
# 1630   Here’s where Colorado stands with Coronavirus ...  INFORMATIVE
# 197    Public Health Report 27 confirmed positive cas...  INFORMATIVE
# 9367   UPDATE on coronavirus (#COVID19) testing in th...  INFORMATIVE
# 4673   "Sadly, we can confirm that a patient who was ...  INFORMATIVE
# 9031   There have no been five coronavirus deaths in ...  INFORMATIVE
#
#        prob_informative  keyword_score  \
# 5861           0.969611             10
# 494            0.940412             10
# 10094          0.926178             10
# 8427           0.877758             10
# 1972           0.996509              9
# 487            0.994000              9
# 3842           0.993005              9
# 11793          0.992751              9
# 6947           0.991456              9
# 9776           0.988734              9
# 1987           0.988579              9
# 8797           0.988562              9
# 1213           0.987584              9
# 8461           0.986936              9
# 5469           0.980983              9
# 1630           0.980823              9
# 197            0.980740              9
# 9367           0.979362              9
# 4673           0.970869              9
# 9031           0.965255              9
#
#                                         matched_keywords  final_score  \
# 5861   {'case_growth': ['tested positive'], 'death_se...           15
# 494    {'case_growth': ['tested positive'], 'death_se...           15
# 10094  {'case_growth': ['new cases', 'confirmed cases...           15
# 8427   {'case_growth': ['cases'], 'death_severity': [...           15
# 1972   {'case_growth': ['confirmed', 'tested positive...           14
# 487    {'case_growth': ['confirmed', 'tested positive...           14
# 3842   {'case_growth': ['tested positive', 'cases'], ...           14
# 11793  {'case_growth': ['confirmed', 'tested positive...           14
# 6947   {'case_growth': ['tested positive'], 'death_se...           14
# 9776   {'case_growth': ['tested positive', 'cases'], ...           14
# 1987   {'case_growth': ['confirmed', 'tested positive...           14
# 8797   {'case_growth': ['new cases', 'cases'], 'death...           14
# 1213   {'case_growth': ['tested positive'], 'death_se...           14
# 8461   {'case_growth': ['tested positive'], 'death_se...           14
# 5469   {'case_growth': ['tested positive'], 'death_se...           14
# 1630   {'case_growth': ['positive cases', 'cases'], '...           14
# 197    {'case_growth': ['confirmed', 'positive cases'...           14
# 9367   {'case_growth': ['tested positive'], 'death_se...           14
# 4673   {'case_growth': ['tested positive'], 'death_se...           14
# 9031   {'case_growth': ['tested positive'], 'death_se...           14
#
#       alert_level
# 5861         HIGH
# 494          HIGH
# 10094        HIGH
# 8427         HIGH
# 1972         HIGH
# 487          HIGH
# 3842         HIGH
# 11793        HIGH
# 6947         HIGH
# 9776         HIGH
# 1987         HIGH
# 8797         HIGH
# 1213         HIGH
# 8461         HIGH
# 5469         HIGH
# 1630         HIGH
# 197          HIGH
# 9367         HIGH
# 4673         HIGH
# 9031         HIGH

# %%
# CSV 저장
unlabeled_risk_df.to_csv("baseline_with_keyword_risk_results.csv", index=False)
print("saved: baseline_with_keyword_risk_results.csv")
# Out:
# saved: baseline_with_keyword_risk_results.csv

# %%
# CSV 내용확인
result_df = pd.read_csv("baseline_with_keyword_risk_results.csv")
result_df.head()
# Out:
#                                                 Text     pred_label  \
# 0  Fox Business' Lou Dobbs Self-Quarantines After...    INFORMATIVE
# 1  Results from UVRI showed the sample is positiv...    INFORMATIVE
# 2  Today or tomorrow, the number of #COVIDー19 cas...  UNINFORMATIVE
# 3  Ramsey County veterans experiencing negative f...  UNINFORMATIVE
# 4  The #Covid19 death rate in New Orleans is 7x h...  UNINFORMATIVE
#
#    prob_informative  prob_uninformative  keyword_score  \
# 0          0.626790            0.373210              1
# 1          0.909645            0.090355              2
# 2          0.289060            0.710940              2
# 3          0.244093            0.755907              0
# 4          0.357295            0.642705              3
#
#                     matched_keywords  final_score alert_level  alert_rank
# 0  {'testing_quarantine': ['tests']}            5      MEDIUM           2
# 1     {'case_growth': ['confirmed']}            7      MEDIUM           2
# 2         {'case_growth': ['cases']}            2         LOW           1
# 3                                 {}            0         LOW           1
# 4      {'death_severity': ['death']}            3         LOW           1

# %%
result_df.columns
# Out:
# Index(['Text', 'pred_label', 'prob_informative', 'prob_uninformative',
#        'keyword_score', 'matched_keywords', 'final_score', 'alert_level',
#        'alert_rank'],
#       dtype='object')

# %%
# 전체 행 개수 확인
result_df.shape
# Out:
# (12000, 9)

# %%
#alert level 분포 확인
result_df["alert_level"].value_counts()
# Out:
# alert_level
# LOW       5765
# MEDIUM    5164
# HIGH      1071
# Name: count, dtype: int64

# %%
#정보성 분류 결과 확인
result_df["pred_label"].value_counts()
# Out:
# pred_label
# INFORMATIVE      6949
# UNINFORMATIVE    5051
# Name: count, dtype: int64
